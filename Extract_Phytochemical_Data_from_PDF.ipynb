# %% [markdown]
# <a href="https://colab.research.google.com/github/MutonyiLewis/Mes-Project/blob/main/Extract_Phytochemical_Data_from_PDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PyMuPDF unidecode fuzzywuzzy pdfplumber
# Out:
# Requirement already satisfied: PyMuPDF in /usr/local/lib/python3.11/dist-packages (1.26.3)
# Requirement already satisfied: unidecode in /usr/local/lib/python3.11/dist-packages (1.4.0)
# Requirement already satisfied: fuzzywuzzy in /usr/local/lib/python3.11/dist-packages (0.18.0)
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.7-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 1.5 MB/s eta 0:00:00
# Collecting pdfminer.six==20250506 (from pdfplumber)
#   Downloading pdfminer_six-20250506-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.11/dist-packages (from pdfplumber) (11.2.1)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six==20250506->pdfplumber) (3.4.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six==20250506->pdfplumber) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (2.22)
# Downloading pdfplumber-0.11.7-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 4.5 MB/s eta 0:00:00
# Downloading pdfminer_six-20250506-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 61.1 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 79.3 MB/s eta 0:00:00
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
# Successfully installed pdfminer.six-20250506 pdfplumber-0.11.7 pypdfium2-4.30.1

# %% [markdown]
# #### Extract raw data from PDF

# %%
import pdfplumber
import pandas as pd
from unidecode import unidecode


pdf_path = '/content/FF Components and their Benefits.pdf'

records = []

with pdfplumber.open(pdf_path) as pdf:
    for page in pdf.pages:
        tables = page.extract_tables()
        for table in tables:
            for row in table:
                if not any(row): continue
                if "bioactive" in str(row[0]).lower(): continue
                if len(row) < 2: continue  # skip malformed rows

                molecule = unidecode(str(row[0])).strip()
                source = unidecode(str(row[1])).strip() if len(row) > 1 else ""
                benefits = unidecode(str(row[2])).strip() if len(row) > 2 else ""
                intake = unidecode(str(row[3])).strip() if len(row) > 3 else ""

                records.append({
                    "name": molecule,
                    "category": None,
                    "food_sources": source,
                    "benefits": benefits,
                    "intake_example": intake
                })

# %% [markdown]
# ## Backfill categories

# %%
category_map = {
    'Lycopene': 'Carotenoids',
    'Flavonoids': 'Carotenoids',
    'Luteolin': 'Bioactive Carbonyls',
    'Apigenin': 'Bioactive Carbonyls',
    'Tangeritin': 'Bioactive Carbonyls',
    'Kaempferol': 'Bioactive Carbonyls',
    'Galangin': 'Bioactive Carbonyls',
    'Hesperitin': 'Bioactive Carbonyls',
    'Silymarin': 'Bioactive Carbonyls',
    'Epigallocatechin-3-gallate Epicatechin': 'Bioactive Carbonyls',
    'Curcumin': 'Bioactive Carbonyls',
    'Resveratrol/Piceatannol': 'Bioactive Carbonyls',
    'Polyphenols Ellagin acid Ellagitannins': 'Bioactive Carbonyls',
    'Soy isoflavones, Genistein, Daidzein,glyceollins': 'Bioactive Carbonyls',
    'Omega-3 fatty acids': 'Bioactive Carbonyls',
    'Omega-3 fatty acids,Lignans': 'Bioactive Carbonyls',
    'Alicin,DAS,DADS,Ajoene': 'Bioactive Carbonyls',
    'Gingerols,Shoagols,Zerumbone': 'Bioactive Carbonyls',
    'Insoluble fiber': 'Dietary (functional and total) Fiber',
    'Soluble fiber': 'Dietary (functional and total) Fiber',
    'Whole grains': 'Dietary (functional and total) Fiber',
    'Selenium': 'Minerals'
}

# Apply map
for r in records:
  r['category'] = category_map.get(r['name'], 'UNKNOWN')

# %% [markdown]
# ## Build DataFrame and Add ID

# %%
df = pd.DataFrame(records)
df["phyto_id"] = range(1, len(df) + 1)

# Optional: Clean up entries
df["food_sources"] = df["food_sources"].str.replace(r"\n", ", ", regex=True)
df["benefits"] = df["benefits"].str.replace(r"\n", " ", regex=True)

# %%
df.head(20)
# Out:
#                                                  name category  \
# 0                                    CancerPrevention     None
# 1                                         Carotenoids     None
# 2                                            Lycopene     None
# 3   Flavonoids(quercetin,\nkaempferol,rutin),\nphe...     None
# 4                                            Luteolin     None
# 5                                            Apigenin     None
# 6                                          Tangeritin     None
# 7                                          Kaempferol     None
# 8                                            Galangin     None
# 9                                          Hesperitin     None
# 10                                          Silymarin     None
# 11          Epigallocatechin-3-\ngallate\nEpicatechin     None
# 12                                                        None
# 13                                           Curcumin     None
# 14                            Resveratrol/Piceatannol     None
# 15            Polyphenols\nEllaginacid\nEllagitannins     None
# 16  Soyisoflavones,\nGenistein,\nDaidzein,\nglyceo...     None
# 17                                                        None
# 18                                  Omega-3fattyacids     None
# 19                        Omega-3fattyacids,\nLignans     None
#
#                                          food_sources  \
# 0
# 1                                                None
# 2   tomatoes,, processedtomato, products,, waterme...
# 3                     Stinging nettle, (Urticadioica)
# 4   Broccoli, green, pepper, parsley,, oregano, ca...
# 5   Many fruits and, vegetables, parsley,, celery,...
# 6                                         Citruspeels
# 7   Apples, potatoes,, onions, broccoli,, brussels...
# 8                                            Proposis
# 9                                        Citrusfruits
# 10                                        Milkthistle
# 11                                           Greentea
# 12
# 13                                           Turmeric
# 14                                    Grapes, Berries
# 15                                        Pomegranate
# 16                                            Soybean
# 17
# 18                                            Fishoil
# 19                                           Flaxseed
#
#                                              benefits  \
# 0
# 1                                                None
# 2   Prostatecancer -reducesoxidativestress through...
# 3   Flavonoidshave antioxidantandanti- inflammator...
# 4                            Anticarcinogenicactivity
# 5                            Anticarcinogenicactivity
# 6                            Anticarcinogenicactivity
# 7                            Anticarcinogenicactivity
# 8                            Anticarcinogenicactivity
# 9                            Anticarcinogenicactivity
# 10                           Anticarcinogenicactivity
# 11  Coloncancer -inducesapoptosis Skincancer - pro...
# 12  arrest by altering the expression of cell cycl...
# 13  Colorectalcancer - inhibits transcription via ...
# 14  Skincancer - inhibit DNA strand breakage Lungc...
# 15  Breastcancer - arrest cell cycle in GO/GI and ...
# 16  Breastcancer - nuclear factor-kappa B (NF-kapp...
# 17  G2/Mphase Lungcancer - induction of apoptosis ...
# 18  Coloncancer -caspase-8activation Breastcancer ...
# 19  Prostatecancer - decreased mRNA expressions of...
#
#                                        intake_example  phyto_id
# 0                                                             1
# 1                                                             2
# 2   -consumptionof160gm/d\ntomatosaucedecreasesLDL...         3
# 3                                                             4
# 4                                                             5
# 5                                                             6
# 6                                                             7
# 7                                                             8
# 8                                                             9
# 9                                                            10
# 10                                                           11
# 11                                                           12
# 12                                                           13
# 13                                                           14
# 14                                                           15
# 15                                                           16
# 16                                                           17
# 17                                                           18
# 18                                                           19
# 19                                                           20

# %% [markdown]
# ##  Save the Final Table

# %%
df.to_csv("phytochemicals.csv", index=False)

# %% [markdown]
# ## Split into Phytochemicl blocks

# %%
import re

full_text = re.sub(r'\n{2,}', '\n', full_text)

# Split where a new section likely starts with a title (capitalized)
blocks = re.split(r"\n(?=[A-Z][a-z]+(?:\s[A-Z][a-z]+)*\s*)", full_text)
blocks = [b.strip() for b in blocks if b.strip()]  # Remove empty blocks

# %%
print(blocks)
# Out:
# ['1 | P a g e', 'Functional Foods Components and their Benefits', 'Cancer Prevention', 'Bioactive molecules', 'Source(s)', 'Potential Benefits(s)', 'Carotenoids', 'Lycopene\ntomatoes,\nprocessed tomato\nproducts,\nwatermelon,\nred/pink\ngrapefruit', 'Prostate cancer\n- reduces oxidative stress\nthrough modulation of\nantioxidant defence\nsystem', 'Skin cancer\n- increases nuclear NF-\nE2-related factor-2', 'Colon cancer\n- inhibit DNA damage\n- down regulation of\ncyclin D1, Bcl-2 and', 'Bcl-xL expression\n-consumption of 160 gm/d\ntomato sauce decreases LDL\ncholesterol', 'Flavonoids (quercetin,\nkaempferol, rutin),\nphenolic compounds,\norganic acids, vitamins,\nminerals', 'Stinging\nnettle\n(Urtica dioica)\n\uf06c', 'Flavonoids have\nantioxidant and anti-\ninflammatory\nproperties that may\nlimit oxidative\ndamage responsible\nfor some chronic\ndiseases such as\ncancer\n\uf06c\nhas anti-tumor\nactivity against\nprostate cancer\n\uf06c', 'Bioactive Carbonyls', 'Luteolin', 'Broccoli,\ngreen\npepper,\nparsley,\noregano,\ncarrots,\nrosemary', 'Anticarcinogenic activity', 'Apigenin', 'Many\nfruits\nand\nvegetables, parsley,\ncelery, chamomile\ntea', 'Anticarcinogenic activity', 'Tangeritin', 'Citrus peels', 'Anticarcinogenic activity', 'Kaempferol', 'Apples,\npotatoes,\nonions,\nbroccoli,\nbrussels\nsprouts,\nsquash,\ncucumbers,\nlettuce,\ngreen\nbeans,\npeaches,\nblackberries,\nraspberries,\nspinach', 'Anticarcinogenic activity', 'Galangin', 'Proposis', 'Anticarcinogenic activity', 'Hesperitin', 'Citrus fruits', 'Anticarcinogenic activity', 'Silymarin', 'Milk thistle', 'Anticarcinogenic activity', 'Epigallocatechin-3-\ngallate', 'Epicatechin', 'Green tea', 'Colon cancer\n- induces apoptosis', 'Skin cancer\n- promotes cell growth\n2 | P a g e\narrest\nby\naltering\nthe\nexpression of cell cycle\nregulatory protein', 'Lung cancer\n-', 'Activating\nkiller\ncaspases', 'Prostate cancer\n-\nsuppressing\nnuclear\nfactor\nkappa-B\nactivation', 'Breast cancer\n- regulates and promotes\nIL-23 dependent DNA\n-\nmodulates\nsignal\ntransduction pathways', 'Curcumin', 'Turmeric', 'Colorectal cancer\n- inhibits transcription via\nAP-1\n-\nsuppresses\ncell\nproliferation\n- inhibits metastasis\n- apoptosis\n- G(1)/S arrest of the cell\ncycle\n-\nboosting\nantioxidant\ndefences', 'Resveratrol/Piceatannol', 'Grapes', 'Berries', 'Skin cancer\n-\ninhibit\nDNA\nstrand\nbreakage', 'Lung cancer\n-\ninhibitors\nof\ntopoisamerase I', 'Colorectal cancer\n- antimetastatic effects', 'Breast cancer\n- cell cycle arrest\n-\ndown-regulation\nof\nP13Kinase\nto\ninduce\napoptosis', 'Polyphenols', 'Ellagin acid', 'Ellagitannins', 'Pomegranate', 'Breast cancer\n-\narrest\ncell\ncycle\nin\nGO/GI\nand\nG(2)/M\nphase', 'Colon cancer\n- apoptosis', 'Lung cancer\n- antiproliferative', 'Skin cancer\n- antiaromatase activity\n-\ninhibited\nNF-kappaB\nand cell viability\n-\nmodulating', 'Bax:Bcl-2\nproteins', 'Soy isoflavones,', 'Genistein,', 'Daidzein,\nglyceollins', 'Soybean', 'Breast cancer\n- nuclear factor-kappa B\n(NF-kappaB) pathway', 'Gastric cancer\n- decreases risk for gastric\nand lung cancer', 'Ovarian cancer\n-\narrest\ncell\ncycle\nin\n3 | P a g e\nG2/M phase', 'Lung cancer\n- induction of apoptosis\nand\nrepair\nof\nDNA\ndamage\n- induces expression of\np21, p53, and caspase-3\nproteins\n-\ninhibition\nof\nVEGF\nexpression', 'Omega-3 fatty acids', 'Fish oil', 'Colon cancer\n- caspase-8 activation', 'Breast cancer\n- induction of apoptosis\n-\nenhance\nlipid\nperoxidation\n-\nmodulation\nof\nmitochadrial\ncalcium\nhomeostasis\n- enhanced production of\nreactive oxygen species\n- activation of p53', 'Omega-3 fatty acids,', 'Lignans', 'Flaxseed', 'Prostate cancer\n-\ndecreased\nmRNA\nexpressions\nof', 'Bcl2,\ncyclin D1, pS2, ERalpha', 'Breast cancer\n- apoptosis\n-\ndecreased\nVEGF\nsecretion\n-\nenhancement\nin\nantioxidant\ndefence\nenzymes activities\n- reduced tumor growth\nand metastasis', 'Alicin,\nDAS,\nDADS', 'Ajoene, etc', 'Garlic', 'Gastrointestina ...

# %% [markdown]
# ##Parse each block

# %%
import pandas as pd

phyto_data = []

for block in blocks:
  lines = block.strip().split('\n')

  # First line prob the compound
  name = lines[0].strip().split()[0]

  #
